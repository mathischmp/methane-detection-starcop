# %% [markdown]
# <div align="center">
#
# # Methan detection - STARCOP dataset
#
# </div>

# %%
# !git clone https://github.com/mathischmp/methane-detection-starcop.git
# %cd methane-detection-starcop
# !pip install -e .
# Out:
# Cloning into 'methane-detection-starcop'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 36 (delta 8), reused 29 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (36/36), 472.56 KiB | 4.72 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# /content/methane-detection-starcop
# Obtaining file:///content/methane-detection-starcop
#   Preparing metadata (setup.py) ... done
# Installing collected packages: methan_detection
#   Attempting uninstall: methan_detection
#     Found existing installation: methan_detection 0.1
#     Uninstalling methan_detection-0.1:
#       Successfully uninstalled methan_detection-0.1
#   Running setup.py develop for methan_detection
# Successfully installed methan_detection-0.1

# %%
import sys
import pandas as pd
import sys
from pathlib import Path


from methan_detection.pipeline import Pipeline

# %%
pipeline = Pipeline(training_type="easy")
data = pipeline.run()
# Out:
# Loading CSV file from ..\data\STARCOP_train_easy\train_easy.csv...
# Stratifying qplume into 10 bins
#
# Fold distribution:
# fold
# 0    130
# 1     97
# 2    116
# 3    100
# 4    116
# Name: count, dtype: int64
# c:\Users\gamer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_split.py:1037: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
